# %% [markdown]
# # Setup

# %%
# !pip install -U pip
# !pip install accelerate==0.20.3
# !pip install appdirs==1.4.4
# !pip install bitsandbytes==0.37.2
# !pip install datasets==2.10.1
# !pip install fire==0.5.0
# !pip install git+https://github.com/huggingface/peft.git
# !pip install git+https://github.com/huggingface/transformers.git
# !pip install torch==2.0.0
# !pip install sentencepiece==0.1.97
# !pip install tensorboardX==2.6
# !pip install gradio==3.23.0
# !pip install seaborn
# !pip install --upgrade gdown
# Out:
# Requirement already satisfied: pip in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (23.1.2)
# Requirement already satisfied: accelerate==0.20.3 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from accelerate==0.20.3) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from accelerate==0.20.3) (23.1)
# Requirement already satisfied: psutil in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from accelerate==0.20.3) (5.9.5)
# Requirement already satisfied: pyyaml in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from accelerate==0.20.3) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from accelerate==0.20.3) (2.0.0)
# Requirement already satisfied: filelock in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (3.12.2)
# Requirement already satisfied: typing-extensions in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (4.7.0)
# Requirement already satisfied: sympy in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (1.12)
# Requirement already satisfied: networkx in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (3.1)
# Requirement already satisfied: jinja2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.6.0->accelerate==0.20.3) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->accelerate==0.20.3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from sympy->torch>=1.6.0->accelerate==0.20.3) (1.3.0)
# Requirement already satisfied: appdirs==1.4.4 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (1.4.4)
# Requirement already satisfied: bitsandbytes==0.37.2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (0.37.2)
# Requirement already satisfied: datasets==2.10.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (2.10.1)
# Requirement already satisfied: numpy>=1.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (1.25.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (12.0.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (0.3.6)
# Requirement already satisfied: pandas in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (4.65.0)
# Requirement already satisfied: xxhash in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (3.2.0)
# Requirement already satisfied: multiprocess in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (2023.6.0)
# Requirement already satisfied: aiohttp in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (0.16.2)
# Requirement already satisfied: packaging in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (23.1)
# Requirement already satisfied: responses<0.19 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from datasets==2.10.1) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->datasets==2.10.1) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->datasets==2.10.1) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->datasets==2.10.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->datasets==2.10.1) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->datasets==2.10.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->datasets==2.10.1) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->datasets==2.10.1) (1.3.1)
# Requirement already satisfied: filelock in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.1) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.10.1) (4.7.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests>=2.19.0->datasets==2.10.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests>=2.19.0->datasets==2.10.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests>=2.19.0->datasets==2.10.1) (2023.5.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from pandas->datasets==2.10.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from pandas->datasets==2.10.1) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from pandas->datasets==2.10.1) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.10.1) (1.16.0)
# Requirement already satisfied: fire==0.5.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: six in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from fire==0.5.0) (1.16.0)
# Requirement already satisfied: termcolor in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from fire==0.5.0) (2.3.0)
# Collecting git+https://github.com/huggingface/peft.git
#   Cloning https://github.com/huggingface/peft.git to /private/var/folders/zp/gf3jrfl17nbcfvwdxm86d30c0000gn/T/pip-req-build-enbr221j
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /private/var/folders/zp/gf3jrfl17nbcfvwdxm86d30c0000gn/T/pip-req-build-enbr221j
#   Resolved https://github.com/huggingface/peft.git to commit 06fd06a4d2e8ed8c3a253c67d9c3cb23e0f497ad
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from peft==0.4.0.dev0) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from peft==0.4.0.dev0) (23.1)
# Requirement already satisfied: psutil in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from peft==0.4.0.dev0) (5.9.5)
# Requirement already satisfied: pyyaml in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from peft==0.4.0.dev0) (6.0)
# Requirement already satisfied: torch>=1.13.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from peft==0.4.0.dev0) (2.0.0)
# Requirement already satisfied: transformers in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from peft==0.4.0.dev0) (4.31.0.dev0)
# Requirement already satisfied: accelerate in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from peft==0.4.0.dev0) (0.20.3)
# Requirement already satisfied: safetensors in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from peft==0.4.0.dev0) (0.3.1)
# Requirement already satisfied: filelock in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0.dev0) (3.12.2)
# Requirement already satisfied: typing-extensions in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0.dev0) (4.7.0)
# Requirement already satisfied: sympy in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0.dev0) (1.12)
# Requirement already satisfied: networkx in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0.dev0) (3.1)
# Requirement already satisfied: jinja2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0.dev0) (3.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers->peft==0.4.0.dev0) (0.16.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers->peft==0.4.0.dev0) (2022.7.9)
# Requirement already satisfied: requests in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers->peft==0.4.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers->peft==0.4.0.dev0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers->peft==0.4.0.dev0) (4.65.0)
# Requirement already satisfied: fsspec in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers->peft==0.4.0.dev0) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft==0.4.0.dev0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->transformers->peft==0.4.0.dev0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->transformers->peft==0.4.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->transformers->peft==0.4.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->transformers->peft==0.4.0.dev0) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from sympy->torch>=1.13.0->peft==0.4.0.dev0) (1.3.0)
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /private/var/folders/zp/gf3jrfl17nbcfvwdxm86d30c0000gn/T/pip-req-build-hr8qaatj
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /private/var/folders/zp/gf3jrfl17nbcfvwdxm86d30c0000gn/T/pip-req-build-hr8qaatj
#   Resolved https://github.com/huggingface/transformers.git to commit 35eac0df75c692c5b93c12f7eaf3279cab8bd7ce
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (0.16.2)
# Requirement already satisfied: numpy>=1.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (2022.7.9)
# Requirement already satisfied: requests in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from transformers==4.31.0.dev0) (4.65.0)
# Requirement already satisfied: fsspec in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0.dev0) (4.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->transformers==4.31.0.dev0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->transformers==4.31.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->transformers==4.31.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->transformers==4.31.0.dev0) (2023.5.7)
# Requirement already satisfied: torch==2.0.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: filelock in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch==2.0.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch==2.0.0) (4.7.0)
# Requirement already satisfied: sympy in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch==2.0.0) (1.12)
# Requirement already satisfied: networkx in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch==2.0.0) (3.1)
# Requirement already satisfied: jinja2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from torch==2.0.0) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from jinja2->torch==2.0.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from sympy->torch==2.0.0) (1.3.0)
# Collecting sentencepiece==0.1.97
#   Using cached sentencepiece-0.1.97.tar.gz (524 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sentencepiece
#   Building wheel for sentencepiece (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [81 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-311
#       creating build/lib.macosx-10.9-x86_64-cpython-311/sentencepiece
#       copying src/sentencepiece/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-311/sentencepiece
#       copying src/sentencepiece/_version.py -> build/lib.macosx-10.9-x86_64-cpython-311/sentencepiece
#       copying src/sentencepiece/sentencepiece_model_pb2.py -> build/lib.macosx-10.9-x86_64-cpython-311/sentencepiece
#       copying src/sentencepiece/sentencepiece_pb2.py -> build/lib.macosx-10.9-x86_64-cpython-311/sentencepiece
#       running build_ext
#       /bin/sh: pkg-config: command not found
#       Cloning into 'sentencepiece'...
#       Note: switching to '58f256cf6f01bb86e6fa634a5cc560de5bd1667d'.
#
#       You are in 'detached HEAD' state. You can look around, make experimental
#       changes and commit them, and you can discard any commits you make in this
#       state without impacting any branches by switching back to a branch.
#
#       If you want to create a new branch to retain commits you create, you may
#       do so (now or later) by using -c with the switch command. Example:
#
#         git switch -c <new-branch-name>
#
#       Or undo this operation with:
#
#         git switch -
#
#       Turn off this advice by setting config variable advice.detachedHead to false
#
#       ./build_bundled.sh: line 19: cmake: command not found
#       ./build_bundled.sh: line 20: nproc: command not found
#       ./build_bundled.sh: line 20: cmake: command not found
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/zp/gf3jrfl17nbcfvwdxm86d30c0000gn/T/pip-install-8nabb8ax/sentencepiece_be1f67eda940436f815bff24c4812bd4/setup.py", line 136, in <module>
#           setup(
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/__init__.py", line 107, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/dist.py", line 1234, in run_command
#           super().run_command(command)
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/wheel/bdist_wheel.py", line 343, in run
#           self.run_command("build")
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/dist.py", line 1234, in run_command
#           super().run_command(command)
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/command/build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/dist.py", line 1234, in run_command
#           super().run_command(command)
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/command/build_ext.py", line 84, in run
#           _build_ext.run(self)
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py", line 345, in run
#           self.build_extensions()
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py", line 467, in build_extensions
#           self._build_extensions_serial()
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py", line 493, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/private/var/folders/zp/gf3jrfl17nbcfvwdxm86d30c0000gn/T/pip-install-8nabb8ax/sentencepiece_be1f67eda940436f815bff24c4812bd4/setup.py", line 89, in build_extension
#           subprocess.check_call(['./build_bundled.sh', __version__])
#         File "/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['./build_bundled.sh', '0.1.97']' returned non-zero exit status 127.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for sentencepiece
#   Running setup.py clean for sentencepiece
# Failed to build sentencepiece
# ERROR: Could not build wheels for sentencepiece, which is required to install pyproject.toml-based projects
# Requirement already satisfied: tensorboardX==2.6 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (2.6)
# Requirement already satisfied: numpy in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from tensorboardX==2.6) (1.25.0)
# Requirement already satisfied: packaging in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from tensorboardX==2.6) (23.1)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from tensorboardX==2.6) (3.20.3)
# Requirement already satisfied: gradio==3.23.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (3.23.0)
# Requirement already satisfied: aiofiles in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (23.1.0)
# Requirement already satisfied: aiohttp in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (3.8.4)
# Requirement already satisfied: altair>=4.2.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (5.0.1)
# Requirement already satisfied: fastapi in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (0.100.0)
# Requirement already satisfied: ffmpy in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (0.3.0)
# Requirement already satisfied: fsspec in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (2023.6.0)
# Requirement already satisfied: httpx in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (0.24.1)
# Requirement already satisfied: huggingface-hub in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (0.16.2)
# Requirement already satisfied: jinja2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (2.2.0)
# Requirement already satisfied: markupsafe in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (2.1.3)
# Requirement already satisfied: matplotlib in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (0.3.3)
# Requirement already satisfied: numpy in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (1.25.0)
# Requirement already satisfied: orjson in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (3.9.2)
# Requirement already satisfied: pandas in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (2.0.3)
# Requirement already satisfied: pillow in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (9.5.0)
# Requirement already satisfied: pydantic in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (1.10.11)
# Requirement already satisfied: pydub in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (0.25.1)
# Requirement already satisfied: python-multipart in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (0.0.6)
# Requirement already satisfied: pyyaml in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (6.0)
# Requirement already satisfied: requests in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (2.31.0)
# Requirement already satisfied: semantic-version in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (2.10.0)
# Requirement already satisfied: typing-extensions in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (4.7.0)
# Requirement already satisfied: uvicorn in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (0.22.0)
# Requirement already satisfied: websockets>=10.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gradio==3.23.0) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from altair>=4.2.0->gradio==3.23.0) (4.17.3)
# Requirement already satisfied: toolz in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from altair>=4.2.0->gradio==3.23.0) (0.12.0)
# Requirement already satisfied: filelock in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from huggingface-hub->gradio==3.23.0) (3.12.2)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from huggingface-hub->gradio==3.23.0) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from huggingface-hub->gradio==3.23.0) (23.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.23.0) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.23.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from pandas->gradio==3.23.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from pandas->gradio==3.23.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from pandas->gradio==3.23.0) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->gradio==3.23.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->gradio==3.23.0) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->gradio==3.23.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->gradio==3.23.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->gradio==3.23.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->gradio==3.23.0) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from aiohttp->gradio==3.23.0) (1.3.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from fastapi->gradio==3.23.0) (0.27.0)
# Requirement already satisfied: certifi in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from httpx->gradio==3.23.0) (2023.5.7)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from httpx->gradio==3.23.0) (0.17.3)
# Requirement already satisfied: idna in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from httpx->gradio==3.23.0) (3.4)
# Requirement already satisfied: sniffio in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from httpx->gradio==3.23.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib->gradio==3.23.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib->gradio==3.23.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib->gradio==3.23.0) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib->gradio==3.23.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib->gradio==3.23.0) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests->gradio==3.23.0) (1.26.16)
# Requirement already satisfied: click>=7.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from uvicorn->gradio==3.23.0) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from uvicorn->gradio==3.23.0) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from httpcore<0.18.0,>=0.15.0->httpx->gradio==3.23.0) (3.7.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.23.0) (0.19.3)
# Requirement already satisfied: uc-micro-py in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.23.0) (1.0.2)
# Requirement already satisfied: six>=1.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->gradio==3.23.0) (1.16.0)
# Requirement already satisfied: seaborn in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: gdown in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (4.7.1)
# Requirement already satisfied: filelock in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests[socks]->gdown) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests[socks]->gdown) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests[socks]->gdown) (2023.5.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
import transformers
import textwrap
from transformers import LlamaTokenizer, LlamaForCausalLM
import os
import sys
from typing import List
 
from peft import (
    LoraConfig,
    get_peft_model,
    get_peft_model_state_dict,
    prepare_model_for_int8_training,
)
 
import fire
import torch
from datasets import load_dataset
import pandas as pd
 
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from pylab import rcParams
 
# %matplotlib inline
sns.set(rc={'figure.figsize':(10, 7)})
sns.set(rc={'figure.dpi':100})
sns.set(style='white', palette='muted', font_scale=1.2)
 
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DEVICE
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# CUDA SETUP: Required library version not found: libsbitsandbytes_cpu.so. Maybe you need to compile it from source?
# CUDA SETUP: Defaulting to libbitsandbytes_cpu.so...
# dlopen(/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/libbitsandbytes_cpu.so, 0x0006): tried: '/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/libbitsandbytes_cpu.so' (not a mach-o file), '/System/Volumes/Preboot/Cryptexes/OS/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/libbitsandbytes_cpu.so' (no such file), '/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/libbitsandbytes_cpu.so' (not a mach-o file)
# CUDA SETUP: Required library version not found: libsbitsandbytes_cpu.so. Maybe you need to compile it from source?
# CUDA SETUP: Defaulting to libbitsandbytes_cpu.so...
# dlopen(/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/libbitsandbytes_cpu.so, 0x0006): tried: '/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/libbitsandbytes_cpu.so' (not a mach-o file), '/System/Volumes/Preboot/Cryptexes/OS/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/libbitsandbytes_cpu.so' (no such file), '/Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/libbitsandbytes_cpu.so' (not a mach-o file)
# /Users/adamweinberger/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/bitsandbytes/cextension.py:31: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'cpu'

# %% [markdown]
# # Data

# %%
# !gdown 1xQ89cpZCnafsW5T3G3ZQWvR7q682t2BN
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xQ89cpZCnafsW5T3G3ZQWvR7q682t2BN
# To: /Users/adamweinberger/MIDS/compositional-reasoning-finetuning/bitcoin-sentiment-tweets.csv
# 100%|████████████████████████████████████████| 242k/242k [00:00<00:00, 9.07MB/s]

# %%
# os.rename(f'{os.getcwd()}/compositional-reasoning-finetuning/bitcoin-sentiment-tweets.csv', 
#           f'{os.getcwd()}/data/bitcoin/compositional-reasoning-finetuning/bitcoin-sentiment-tweets.csv')

# %%
df = pd.read_csv("bitcoin-sentiment-tweets.csv")
df.head()
# Out:
#                              date  \
# 0  Fri Mar 23 00:40:40 +0000 2018
# 1  Fri Mar 23 00:40:40 +0000 2018
# 2  Fri Mar 23 00:40:42 +0000 2018
# 3  Fri Mar 23 00:41:04 +0000 2018
# 4  Fri Mar 23 00:41:07 +0000 2018
#
#                                                tweet  sentiment
# 0  @p0nd3ea Bitcoin wasn't built to live on excha...        1.0
# 1  @historyinflicks Buddy if I had whatever serie...        1.0
# 2  @eatBCH @Bitcoin @signalapp @myWickr @Samsung ...        0.0
# 3  @aantonop Even if Bitcoin crash tomorrow morni...        0.0
# 4  I am experimenting whether I can live only wit...        1.0

# %%
df.sentiment.value_counts()
# Out:
# sentiment
#  0.0    860
#  1.0    779
# -1.0    258
# Name: count, dtype: int64

# %%
def sentiment_score_to_name(score: float):
    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    return "Neutral"
 
dataset_data = [
    {
        "instruction": "Detect the sentiment of the tweet.",
        "input": row_dict["tweet"],
        "output": sentiment_score_to_name(row_dict["sentiment"])
    }
    for row_dict in df.to_dict(orient="records")
]
 
dataset_data[0]
# Out:
# {'instruction': 'Detect the sentiment of the tweet.',
#  'input': "@p0nd3ea Bitcoin wasn't built to live on exchanges.",
#  'output': 'Positive'}

# %%
import json
with open("alpaca-bitcoin-sentiment-dataset.json", "w") as f:
   json.dump(dataset_data, f)

# %%
BASE_MODEL = "decapoda-research/llama-7b-hf"
 
model = LlamaForCausalLM.from_pretrained(
    BASE_MODEL,
    load_in_8bit=True,
    torch_dtype=torch.float16,
    device_map="auto",
)
 
tokenizer = LlamaTokenizer.from_pretrained(BASE_MODEL)
 
tokenizer.pad_token_id = (
    0  # unk. we want this to be different from the eos token
)
tokenizer.padding_side = "left"
# Out:
# The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 BASE_MODEL = "decapoda-research/llama-7b-hf"
# ----> 3 model = LlamaForCausalLM.from_pretrained(
#       4     BASE_MODEL,
#       5     load_in_8bit=True,
#       6     torch_dtype=torch.float16,
#       7     device_map="auto",
#       8 )
#      10 tokenizer = LlamaTokenizer.from_pretrained(BASE_MODEL)
#      12 tokenizer.pad_token_id = (
#      13     0  # unk. we want this to be different from the eos token
#      14 )
#
# File ~/opt/anaconda3/envs/compositional_reasoning_finetuning/lib/python3.11/site-packages/transformers/modeling_utils.py:2843, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2839         device_map_without_lm_head = {
#    2840             key: device_map[key] for key in device_map.keys() if key not in modules_to_not_convert
#    2841         }
#    2842         if "cpu" in device_map_without_lm_head.values() or "disk" in device_map_without_lm_head.values():
# -> 2843             raise ValueError(
#    2844                 """
#    2845                 Some modules are dispatched on the CPU or the disk. Make sure you have enough GPU RAM to fit
#    2846                 the quantized model. If you want to dispatch the model on the CPU or the disk while keeping
#    2847                 these modules in 32-bit, you need to set `load_in_8bit_fp32_cpu_offload=True` and pass a custom
#    2848                 `device_map` to `from_pretrained`. Check
#    2849                 https://huggingface.co/docs/transformers/main/en/main_classes/quantization#offload-between-cpu-and-gpu
#    2850                 for more details.
#    2851                 """
#    2852             )
#    2853         del device_map_without_lm_head
#    2855 elif device_map is not None:
#
# ValueError:
#                         Some modules are dispatched on the CPU or the disk. Make sure you have enough GPU RAM to fit
#                         the quantized model. If you want to dispatch the model on the CPU or the disk while keeping
#                         these modules in 32-bit, you need to set `load_in_8bit_fp32_cpu_offload=True` and pass a custom
#                         `device_map` to `from_pretrained`. Check
#                         https://huggingface.co/docs/transformers/main/en/main_classes/quantization#offload-between-cpu-and-gpu
#                         for more details.

# %%
data = load_dataset("json", data_files="alpaca-bitcoin-sentiment-dataset.json")
data["train"]

# %%
def generate_prompt(data_point):
    return f"""Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.  # noqa: E501
### Instruction:
{data_point["instruction"]}
### Input:
{data_point["input"]}
### Response:
{data_point["output"]}"""
 
 
def tokenize(prompt, add_eos_token=True):
    result = tokenizer(
        prompt,
        truncation=True,
        max_length=CUTOFF_LEN,
        padding=False,
        return_tensors=None,
    )
    if (
        result["input_ids"][-1] != tokenizer.eos_token_id
        and len(result["input_ids"]) < CUTOFF_LEN
        and add_eos_token
    ):
        result["input_ids"].append(tokenizer.eos_token_id)
        result["attention_mask"].append(1)
 
    result["labels"] = result["input_ids"].copy()
 
    return result
 
def generate_and_tokenize_prompt(data_point):
    full_prompt = generate_prompt(data_point)
    tokenized_full_prompt = tokenize(full_prompt)
    return tokenized_full_prompt

# %%
train_val = data["train"].train_test_split(
    test_size=200, shuffle=True, seed=42
)
train_data = (
    train_val["train"].map(generate_and_tokenize_prompt)
)
val_data = (
    train_val["test"].map(generate_and_tokenize_prompt)
)

# %%
LORA_R = 8
LORA_ALPHA = 16
LORA_DROPOUT= 0.05
LORA_TARGET_MODULES = [
    "q_proj",
    "v_proj",
]
 
BATCH_SIZE = 128
MICRO_BATCH_SIZE = 4
GRADIENT_ACCUMULATION_STEPS = BATCH_SIZE // MICRO_BATCH_SIZE
LEARNING_RATE = 3e-4
TRAIN_STEPS = 300
OUTPUT_DIR = "experiments"

# %%
model = prepare_model_for_int8_training(model)
config = LoraConfig(
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    target_modules=LORA_TARGET_MODULES,
    lora_dropout=LORA_DROPOUT,
    bias="none",
    task_type="CAUSAL_LM",
)
model = get_peft_model(model, config)
model.print_trainable_parameters()

# %%
training_arguments = transformers.TrainingArguments(
    per_device_train_batch_size=MICRO_BATCH_SIZE,
    gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
    warmup_steps=100,
    max_steps=TRAIN_STEPS,
    learning_rate=LEARNING_RATE,
    fp16=True,
    logging_steps=10,
    optim="adamw_torch",
    evaluation_strategy="steps",
    save_strategy="steps",
    eval_steps=50,
    save_steps=50,
    output_dir=OUTPUT_DIR,
    save_total_limit=3,
    load_best_model_at_end=True,
    report_to="tensorboard"
)

# %%
data_collator = transformers.DataCollatorForSeq2Seq(
    tokenizer, pad_to_multiple_of=8, return_tensors="pt", padding=True
)

# %%
trainer = transformers.Trainer(
    model=model,
    train_dataset=train_data,
    eval_dataset=val_data,
    args=training_arguments,
    data_collator=data_collator
)
model.config.use_cache = False
old_state_dict = model.state_dict
model.state_dict = (
    lambda self, *_, **__: get_peft_model_state_dict(
        self, old_state_dict()
    )
).__get__(model, type(model))
 
model = torch.compile(model)
 
trainer.train()
model.save_pretrained(OUTPUT_DIR)
